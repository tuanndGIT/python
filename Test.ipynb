# %%
import numpy as np
A = np.array([1, 3, 5, 7, 9, 7, 5])
print(A[:-5])
print(A[:-1])
print(A.shape[0])

print("Hello")
# Out:
# [1 3]
# [1 3 5 7 9 7]
# 7

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,6,10], 'bD--')
plt.show()
